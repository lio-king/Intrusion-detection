# %%
#import libraries;
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
#loading the dataset;
dataset=pd.read_csv("Train_data.csv")

# %%
dataset.head()
# Out:
#    duration protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0          icmp       20     2        491          0     0
# 1         0           udp       45     2        146          0     0
# 2         0          icmp       50     4          0          0     0
# 3         0          icmp       25     2        232       8153     0
# 4         0          icmp       25     2        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# ...

# %%
#Now dividing the features and labels
X=dataset.drop(['xAttack'],axis=1)
Y=dataset['xAttack']

# %%
X.head()
# Out:
#    duration protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0          icmp       20     2        491          0     0
# 1         0           udp       45     2        146          0     0
# 2         0          icmp       50     4          0          0     0
# 3         0          icmp       25     2        232       8153     0
# 4         0          icmp       25     2        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_count  dst_host_srv_count  \
# 0               0       0    0  ...             150                  25
# 1               0       0    0  ...             255                   1
# 2               0       0    0  ...             255                  26
# 3               0       0    0  ...              30                 255
# 4               0       0    0  ...             255                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# ...

# %%
pid=pd.get_dummies(X['protocol_type'])

# %%
pid
# Out:
#         icmp  tcp  udp
# 0          1    0    0
# 1          0    0    1
# 2          1    0    0
# 3          1    0    0
# 4          1    0    0
# ...      ...  ...  ...
# 125968     1    0    0
# 125969     0    0    1
# 125970     1    0    0
# 125971     1    0    0
# 125972     1    0    0
#
# [125973 rows x 3 columns]

# %%
X_combine=pd.concat([X,pid],axis=1)

# %%
X_combine
# Out:
#         duration protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0              0          icmp       20     2        491          0     0
# 1              0           udp       45     2        146          0     0
# 2              0          icmp       50     4          0          0     0
# 3              0          icmp       25     2        232       8153     0
# 4              0          icmp       25     2        199        420     0
# ...          ...           ...      ...   ...        ...        ...   ...
# 125968         0          icmp       50     4          0          0     0
# 125969         8           udp       50     2        105        145     0
# 125970         0          icmp       55     2       2231        384     0
# 125971         0          icmp       31     4          0          0     0
# 125972         0          icmp       20     2        151          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_diff_srv_rate  \
# ...

# %%
X_combine = X_combine.drop(['protocol_type'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-340aff1b465f> in <module>
# ----> 1 X_combine = X_combine.drop(['protocol_type'],axis=1)
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
X_combine
# Out:
#         duration  service  flag  src_bytes  dst_bytes  land  wrong_fragment  \
# 0              0       20     2        491          0     0               0
# 1              0       45     2        146          0     0               0
# 2              0       50     4          0          0     0               0
# 3              0       25     2        232       8153     0               0
# 4              0       25     2        199        420     0               0
# ...          ...      ...   ...        ...        ...   ...             ...
# 125968         0       50     4          0          0     0               0
# 125969         8       50     2        105        145     0               0
# 125970         0       55     2       2231        384     0               0
# 125971         0       31     4          0          0     0               0
# 125972         0       20     2        151          0     0               0
#
# ...

# %%
#Now divides the training and testing data
Xtrain,Xtest,ytrain,ytest=train_test_split(X_combine,Y,test_size=0.2)

# %%
Y.unique()
# Out:
# array(['normal', 'dos', 'r2l', 'probe', 'u2r'], dtype=object)

# %%
#using an algorithm 
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(Xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dtree.predict(Xtest)

# %%
score
# Out:
# 0.9976582655288748

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors =5 ).fit(Xtrain, ytrain)

# %%
accuracy = knn.score(Xtest, ytest)

# %%
accuracy
# Out:
# 0.9920222266322684
